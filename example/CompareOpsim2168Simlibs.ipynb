# %%
import simlibs.Simlib as sl
import os
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
loc = '/Users/rbiswas/data/SNDATA/INTERNAL/LSST/simlibs/2_168'

# %%
snanaDeepFileName = os.path.join(loc,'output_opsim2_168.SIMLIB.COADD.DEEP')
snanaDeep =  sl.simlib(snanaDeepFileName)

# %%
snanaDeep.fieldIDs
# Out:
# [2786, 519, 2731, 2412, 2082, 526, 1427, 311, 2712, 764]

# %%
snanaDeep.simlibData(2786).meta['RA']
# Out:
# 150.361542

# %%
opsimSimlib = sl.simlib('Opsim.2.168.Simlib')

# %%
fieldIds = opsimSimlib.fieldIDs

# %%
lst = []
for fieldID in fieldIds:
    # My Calculations from OpSim
    opsimNobs = opsimSimlib.simlibData(fieldID).meta['NOBS']
    # From the SNANA simlibs
    snanaData = snanaDeep.simlibData(fieldID).data
    print snanaData.MJD.min(), snanaData.MJD.max()
    snanaData = snanaData[snanaData['MJD'] < 49561]
    print snanaData.MJD.min(), snanaData.MJD.max()
    snanaNobs = int(snanaData.NOISE.apply(lambda x: round((x / 0.25)**2.)).sum())
    # print fieldID, opsimNobs, snanaNobs,  float(opsimNobs) / float(snanaNobs)
    lst.append([fieldID, opsimNobs, snanaNobs,  float(opsimNobs) / float(snanaNobs)])
# Out:
# 49400.27 52825.082
# 49400.27 49560.988
# 49354.066 52993.172
# 49354.066 49416.082
# 49498.406 52958.098
# 49498.406 49556.305
# 49530.441 52987.121
# 49530.441 49559.359
# 49365.324 52758.0
# 49365.324 49484.984
# 49471.418 52951.195
# 49471.418 49559.184
# 49354.035 52991.344
# 49354.035 49411.051
# 49501.43 52937.051
# 49501.43 49555.156
# 49530.43 52984.23
# 49530.43 49559.332
# 49495.402 52992.074
# 49495.402 49552.277

# %%
df = pd.DataFrame(np.array(lst), columns=['fieldID', 'OpSimVisits', 'SNANAVisits', 'frac'])
df
# Out:
#    fieldID  OpSimVisits  SNANAVisits        frac
# 0     2082         1995         2225    0.896629
# 1      519         2111          298    7.083893
# 2     2731         1095          357    3.067227
# 3     2412         1762           16  110.125000
# 4     2786         1709         1820    0.939011
# 5      526         1859          406    4.578818
# 6     1427         1762           33   53.393939
# 7      311         1781          591    3.013536
# 8     2712         2062           12  171.833333
# 9      764         2779          351    7.917379

# %%
opsimSimlib.simlibData(fieldID).data.MJD.max()
# Out:
# 49560.983

# %%
snanaDeep.simlibData(fieldID).data.MJD.max()
# Out:
# 52825.082000000002

# %%
snanaData.MJD.max()
# Out:
# 49552.277000000002

# %% [markdown]
# ### Example Calculation to demonstrate Estimating the number of exposures in CoAdds

# %%
d = snanaDeep.simlibData(2082).data
d['numCoadded'] = d['NOISE'].apply(lambda x: round((x / 0.25)**2.))
d = d[d['MJD'] < 49561]
d
# Out:
#            MJD   IDEXPT FLT  GAIN  NOISE  SKYSIG  PSF1  PSF2  PSFRatio  \
# 0    49400.281  3602082   g     1   0.90   71.72  1.72     0         0
# 1    49400.270  3602082   r     1   1.15  123.29  1.68     0         0
# 115   34.96   0.005  -99          23
# 116   34.53   0.005  -99          26
# 117   32.76   0.005  -99          20
# 118   33.51   0.005  -99           5
#
# [119 rows x 13 columns]

# %%
0.25 * np.sqrt(13.)
# Out:
# 0.90138781886599728

# %%
d.numCoadded.sum()
# Out:
# 2225.0

# %%
d = snanaDeep.simlibData(519).data
d['numCoadded'] = d['NOISE'].apply(lambda x: round((x / 0.25)**2.))
d = d[d['MJD'] < 49561]
d
# Out:
#           MJD   IDEXPT FLT  GAIN  NOISE  SKYSIG  PSF1  PSF2  PSFRatio  ZPTAVG  \
# 0   49354.070  3600519   g     1   0.83   65.00  1.79     0         0   34.35
# 1   49354.066  3600519   r     1   1.15  119.05  1.78     0         0   35.07
# 2   49354.098  3600519   i     1   1.35  211.92  1.82     0         0   35.21
# 3   49354.090  3600519   z     1   1.27  195.51  1.78     0         0   34.55
# 4   49354.102  3600519   Y     1   1.12  168.15  1.78     0         0   32.78
# 5   49355.211  3610519   Y     1   0.79  125.56  1.63     0         0   32.00
# 6   49356.199  3610519   Y     1   0.61   95.94  1.76     0         0   31.46
# 7   49363.070  3600519   u     1   1.30   26.45  1.50     0         0   33.50
# 8   49365.066  3600519   u     1   1.20   24.38  1.51     0         0   33.33
# 9   49375.070  3600519   g     1   0.79  152.61  2.18     0         0   34.23
# 10  49375.062  3600519   r     1   1.12  197.59  2.18     0         0   35.00
# 11  49375.078  3600519   i     1   1.17  231.20  2.17     0         0   34.92
# 12  49375.090  3600519   z     1   1.41  256.76  2.14     0         0   34.76
# 13  49375.098  3600519   Y     1   1.15  174.93  2.17     0         0   32.83
# 14  49377.188  3610519   z     1   0.43   89.46  2.51     0         0   32.15
# 15  49382.055  3610519   z     1   0.43  137.86  2.14     0         0   32.19
# 16  49411.117  3610519   Y     1   0.35   59.28  1.54     0         0   30.23
# 17  49412.070  3610519   Y     1   0.79  126.16  2.09     0         0   32.00
# 18  49416.082  3610519   r     1   0.35   38.93  2.03     0         0   32.45
#
#     ZPTERR  MAG  numCoadded
# 0    0.005  -99          11
# 1    0.005  -99          21
# 2    0.005  -99          29
# 3    0.005  -99          26
# 4    0.005  -99          20
# 5    0.005  -99          10
# 6    0.005  -99           6
# 7    0.005  -99          27
# 8    0.005  -99          23
# 9    0.005  -99          10
# 10   0.005  -99          20
# 11   0.005  -99          22
# 12   0.005  -99          32
# 13   0.005  -99          21
# 14   0.005  -99           3
# 15   0.005  -99           3
# 16   0.005  -99           2
# 17   0.005  -99          10
# 18   0.005  -99           2

# %%
fig, ax = plt.subplots()
opsimSimlib.simlibData(519).data.hist(column='MJD', by='FLT', histtype='step', ax=ax, lw=2.0, sharex=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x117296b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1172fe790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1174f2690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117574910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1175d9850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11775c690>]], dtype=object)

# %%
d.hist(column='MJD', by='FLT', histtype='step', lw=2.0, ls='dashed', color='r')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x115c08210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11855d490>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1185e0190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118644650>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1186c9490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11865e7d0>]], dtype=object)
