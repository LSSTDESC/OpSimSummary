# %%
from opsimsummary import AllSkyMap, AllSkySNVisualization

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
skyvis = AllSkySNVisualization(bandColorDict=dict(g='g', r='r', i='y'))

# %%
skyvis.generate_image(164, 0, 4, 58950., )

# %%
skyvis.generate_image(0, 0, 4, 58950., )

# %%
skyvis.generate_image(178, 0, 4, 58950., )

# %%
skyvis.generate_image_bg()
# Out:
# (<matplotlib.figure.Figure at 0x10cd6ca10>,
# ...
#  <opsimsummary.visualization.AllSkyMap at 0x10cd50910>)
