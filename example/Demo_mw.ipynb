# %%
# %matplotlib inline

# %%
from opsimsummary import convertToSphericalCoordinates, convertToCelestialCoordinates, MilkyWayExtension, AllSkySNVisualization

# %%
sky = AllSkySNVisualization(bandColorDict=None)

# %%
fig, ax, m = sky.generate_image_bg(mw_alpha=1, bg_color='w')
